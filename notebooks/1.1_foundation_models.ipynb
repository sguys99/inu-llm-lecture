# %% [markdown]
# ## Foundation models

# %% [markdown]
# <div style="text-align: right"> <b>KMYU</b></div>
# <div style="text-align: right"> Initial issue : 2026.03.20 </div>
# <div style="text-align: right"> last update : 2026.03.25 </div>

# %% [markdown]
# 개정 이력
# - `2026.03.20` : 노트북 최초 작성

# %%
import os, sys

from dotenv import load_dotenv
from langchain_anthropic import ChatAnthropic
from langchain.chat_models import init_chat_model

load_dotenv()
# Out:
# True

# %%
print(os.getenv("ANTHROPIC_MODEL"))
# Out:
# claude-haiku-4-5

# %% [markdown]
# ### 1. ChatAnthropic을 활용한 모델 호출

# %%
llm = ChatAnthropic(
    model = os.getenv("ANTHROPIC_MODEL")
)

# %%
llm
# Out:
# ChatAnthropic(profile={'name': 'Claude Haiku 4.5 (latest)', 'release_date': '2025-10-15', 'last_updated': '2025-10-15', 'open_weights': False, 'max_input_tokens': 200000, 'max_output_tokens': 64000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'structured_output': False}, model='claude-haiku-4-5', max_tokens=64000, anthropic_api_url='https://api.anthropic.com', anthropic_api_key=SecretStr('**********'), model_kwargs={})

# %%
response = llm.invoke("달의 수도는 어디야?")
response
# Out:
# AIMessage(content='달은 자연 위성이기 때문에 수도가 없습니다.\n\n달에는 현재 인간이 거주하는 도시나 정부 기관이 없으며, 어떤 국가의 영토도 아닙니다. 달은 1967년 우주조약에 의해 모든 국가가 공동으로 이용할 수 있는 영역으로 지정되었습니다.\n\n혹시 다른 행성이나 천체에 대해 궁금하신가요?', additional_kwargs={}, response_metadata={'id': 'msg_019S3m5mksQA4HHosSL8wUKz', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 19, 'output_tokens': 158, 'server_tool_use': None, 'service_tier': 'standard'}, 'stop_details': None, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--019ef236-cdfe-7d40-9766-b1aa7191a81a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 158, 'total_tokens': 177, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})

# %%
print(response.content)
# Out:
# 달은 자연 위성이기 때문에 수도가 없습니다.
#
# 달에는 현재 인간이 거주하는 도시나 정부 기관이 없으며, 어떤 국가의 영토도 아닙니다. 달은 1967년 우주조약에 의해 모든 국가가 공동으로 이용할 수 있는 영역으로 지정되었습니다.
#
# 혹시 다른 행성이나 천체에 대해 궁금하신가요?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'container': None,
#  'id': 'msg_019S3m5mksQA4HHosSL8wUKz',
#  'model': 'claude-haiku-4-5-20251001',
#  'model_name': 'claude-haiku-4-5-20251001',
#  'model_provider': 'anthropic',
#  'stop_details': None,
#  'stop_reason': 'end_turn',
#  'stop_sequence': None,
#  'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0,
#                               'ephemeral_5m_input_tokens': 0},
#            'cache_creation_input_tokens': 0,
#            'cache_read_input_tokens': 0,
#            'inference_geo': 'not_available',
#            'input_tokens': 19,
#            'output_tokens': 158,
#            'server_tool_use': None,
#            'service_tier': 'standard'}}

# %% [markdown]
# 다른 모델 사용하기

# %%
llm = ChatAnthropic(
    model = "sonnet-4-6"
)
llm
# Out:
# ChatAnthropic(profile={}, model='sonnet-4-6', max_tokens=4096, anthropic_api_url='https://api.anthropic.com', anthropic_api_key=SecretStr('**********'), model_kwargs={})

# %% [markdown]
# ### 2. init_chat_model을 활용한 모델 호출

# %%
llm = init_chat_model(
    model = "claude-haiku-4-5"
)
llm
# Out:
# ChatAnthropic(profile={'name': 'Claude Haiku 4.5 (latest)', 'release_date': '2025-10-15', 'last_updated': '2025-10-15', 'open_weights': False, 'max_input_tokens': 200000, 'max_output_tokens': 64000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'structured_output': False}, model='claude-haiku-4-5', max_tokens=64000, anthropic_api_url='https://api.anthropic.com', anthropic_api_key=SecretStr('**********'), model_kwargs={})

# %%
response = llm.invoke("달의 수도는 어디야?")
response
# Out:
# AIMessage(content='달의 수도는 없습니다. 달은 지구의 위성이며 자체적인 정부나 행정 체계를 갖춘 독립적인 행정 단위가 아니기 때문입니다.\n\n혹시 다른 질문을 하신 건가요?\n- 특정 나라의 수도를 찾으신 건지\n- 달에 대한 다른 정보를 원하신 건지\n\n알려주시면 더 도움을 드리겠습니다!', additional_kwargs={}, response_metadata={'id': 'msg_01N1ox1qvDAbNmuLkzvoFEnT', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 19, 'output_tokens': 155, 'server_tool_use': None, 'service_tier': 'standard'}, 'stop_details': None, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--019ef23a-6f8c-7ba0-b318-3f985f28a758-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 155, 'total_tokens': 174, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})

# %%
pprint(response.content)
# Out:
# ('달의 수도는 없습니다. 달은 지구의 위성이며 자체적인 정부나 행정 체계를 갖춘 독립적인 행정 단위가 아니기 때문입니다.\n'
#  '\n'
#  '혹시 다른 질문을 하신 건가요?\n'
#  '- 특정 나라의 수도를 찾으신 건지\n'
#  '- 달에 대한 다른 정보를 원하신 건지\n'
#  '\n'
#  '알려주시면 더 도움을 드리겠습니다!')

# %% [markdown]
# ### 3. 대화이력 입력하기

# %%
from langchain.messages import HumanMessage, AIMessage

# %%
response = llm.invoke(
    input= [HumanMessage(content="달의 수도는 어디야?")] # 메시지가 사용자로 부터 왔음을 표시
)
response
# Out:
# AIMessage(content='달은 자연 위성이기 때문에 수도가 없습니다.\n\n달은 독립된 국가가 아니라 지구의 위성이므로 정부나 수도를 가지고 있지 않습니다. \n\n혹시 **몰타(Malta)**의 수도를 물어보신 건가요? 그렇다면 몰타의 수도는 **발레타(Valletta)**입니다.', additional_kwargs={}, response_metadata={'id': 'msg_01CWa9xBft7QMDhwrop8XJAg', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 19, 'output_tokens': 131, 'server_tool_use': None, 'service_tier': 'standard'}, 'stop_details': None, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--019ef244-c2bf-7bf0-baac-aee508f082af-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 131, 'total_tokens': 150, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})

# %% [markdown]
# 대화이력을 함께 입력해줘.

# %%
response = llm.invoke(
    input= [HumanMessage(content="달의 수도는 어디야?"),
    AIMessage(content="달의 수도는 Luna City입니다."),
    HumanMessage(content="재미있네요, Luna City에 대해서 더 알려주세요.")]
    )

pprint(response)
# Out:
# AIMessage(content='죄송합니다. 제가 잘못된 정보를 드렸습니다.\n\n달은 인간이 건설한 도시나 수도가 없습니다. 달은 자연 위성이며, 현재 아무도 달에 살고 있지 않습니다.\n\n제가 앞서 "Luna City"라고 답한 것은 실수입니다. 이는 실제 장소가 아니라 과학소설이나 가상의 설정에서 나올 수 있는 이름일 뿐입니다.\n\n정확한 정보를 제공하지 못해 죄송합니다. 궁금한 점이 있으시면 올바른 정보를 드리겠습니다.', additional_kwargs={}, response_metadata={'id': 'msg_014EwHM83jJsRtYhW6i6QgSS', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 62, 'output_tokens': 221, 'server_tool_use': None, 'service_tier': 'standard'}, 'stop_details': None, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--019ef245-82a9-76a0-a13b-21e5b485fa5c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 62, 'output_tokens': 221, 'total_tokens': 283, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})

# %% [markdown]
# ### 4. 에이전트 생성, 호출하기

# %%
from langchain.agents import create_agent

# %%
agent = create_agent(model="claude-haiku-4-5")

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="달의 수도는 어디야?")]} # 메시지가 담긴 딕셔너리를 보내고, 그것이 사용자로 부터 왔음을 표시
)
pprint(response)
# Out:
# {'messages': [HumanMessage(content='달의 수도는 어디야?', additional_kwargs={}, response_metadata={}, id='9b56256f-09da-42ca-8fcc-14412e9dae1b'),
#               AIMessage(content='달은 자연 위성이기 때문에 수도가 없습니다.\n\n달에는 독립적인 국가나 정부가 없고, 따라서 수도도 없습니다. 달 표면에는 여러 국가의 우주 탐사선과 탐사 로봇이 착륙했지만, 현재 달에는 인간이 정착하여 살고 있지 않습니다.\n\n혹시 **몽골의 수도 울란바토르**를 찾고 있었거나, 다른 나라의 수도를 궁금해하셨다면 말씀해 주세요!', additional_kwargs={}, response_metadata={'id': 'msg_01Ft327HsepSUykfymJB9WtR', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 19, 'output_tokens': 193, 'server_tool_use': None, 'service_tier': 'standard'}, 'stop_details': None, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--019ef247-ebbb-79a3-8feb-031def71f0fd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 193, 'total_tokens': 212, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]}

# %% [markdown]
# 마지막 메시지만 추출

# %%
print(response['messages'][-1].content)
# Out:
# 달은 자연 위성이기 때문에 수도가 없습니다.
#
# 달에는 독립적인 국가나 정부가 없고, 따라서 수도도 없습니다. 달 표면에는 여러 국가의 우주 탐사선과 탐사 로봇이 착륙했지만, 현재 달에는 인간이 정착하여 살고 있지 않습니다.
#
# 혹시 **몽골의 수도 울란바토르**를 찾고 있었거나, 다른 나라의 수도를 궁금해하셨다면 말씀해 주세요!

# %% [markdown]
# 대화이력 입력하기

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="달의 수도는 어디야?"),
    AIMessage(content="달의 수도는 Luna City입니다."),
    HumanMessage(content="재미있네요, Luna City에 대해서 더 알려주세요.")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='달의 수도는 어디야?', additional_kwargs={}, response_metadata={}, id='1655108d-9c21-49ea-adb1-3f06345037a5'),
#               AIMessage(content='달의 수도는 Luna City입니다.', additional_kwargs={}, response_metadata={}, id='176ffe47-f0cc-4a44-97cb-3d955fe33c28', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='재미있네요, Luna City에 대해서 더 알려주세요.', additional_kwargs={}, response_metadata={}, id='ce4ab282-ec7d-4d5a-9a27-c0f4b3727cb2'),
#               AIMessage(content='죄송하지만, 제가 앞서 잘못된 정보를 드렸습니다.\n\n달에는 실제로 수도나 도시가 없습니다. 달은 아직 인간이 정착하여 살고 있지 않은 천체이며, "Luna City"는 공상과학 소설이나 게임 등의 가상의 설정일 뿐입니다.\n\n달에 관해 정확한 정보를 드리자면:\n- 달은 지구의 자연위성입니다\n- 1969년 아폴로 11호가 처음으로 인간을 달에 착륙시켰습니다\n- 현재 달에는 영구적인 인간 거주지가 없습니다\n- 미래에 달 기지 건설 계획이 있지만, 아직 실현되지 않았습니다\n\n잘못된 정보를 제공해서 죄송합니다. 앞으로는 더 정확한 정보를 드리도록 하겠습니다.', additional_kwargs={}, response_metadata={'id': 'msg_01V4WT194bxmRvNK4vE69Urh', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 62, 'output_tokens': 313, 'server_tool_use': None, 'service_tier': 'standard'}, 'stop_details': None, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--019ef248-b6f8-7662-b88b-a052a935b877-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 62, 'output_tokens': 313, 'total_tokens': 375, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]}

# %% [markdown]
# ### 5. 스트리밍 출력하기

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="달의 수도인 Luna City에 대해서 알려주세요")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# # Luna City에 대해
#
# 죄송하지만 **Luna City는 실제로 존재하지 않습니다.**
#
# 당신이 말씀하신 내용을 정리해보면:
#
# ## 가능한 해석들
#
# 1. **과학 소설(SF)의 설정**
#    - 달의 도시라는 개념은 SF 문학, 영화, 게임에서 자주 다루어지는 소재입니다
#    - 예: SF 영화나 소설의 미래 배경
#
# 2. **가상의 상황**
#    - 만약 창작물이나 게임에서의 배경이라면, 그 출처를 알려주시면 더 도움을 드릴 수 있습니다
#
# 3. **혼동 가능성**
#    - 지구의 실제 도시를 찾으신 건 아닐까요?
#
# ## 현실의 달
#
# 현재 달에는 인간이 거주하는 도시나 영구 정착지가 없습니다. 다만 우주기관들이 향후 달 기지 건설을 계획하고 있습니다.
#
# 더 자세한 정보가 필요하시거나 다른 것을 알고 싶으시다면 말씀해 주세요! 😊

# %% [markdown]
# 스트리밍 모드 종류
# - "values": 그래프의 전체 상태를 스트리밍
# - "updates": 각 노드의 업데이트만 스트리밍
# - "messages": 메시지 청크(토큰)를 실시간으로 스트리밍 ✅
